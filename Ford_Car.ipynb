# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-149f1620-2691-41a3-b86c-fdd1187a35dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-149f1620-2691-41a3-b86c-fdd1187a35dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = '/content/ford_car_dataset.csv'
df = pd.read_csv(filepath)

# %%
df.head(10)
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5  Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6    Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7  Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8    Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9   Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
df.tail()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961  B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962  B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963  Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964     KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965  Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
# Dataset loaded successfully.
# It contains numerical and categorical columns.
# Price is the target variable.

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(154)

# %%
# No/Removed duplicate rows.
# Missing values checked successfully.

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17966.000000  17966.000000   17966.000000  17966.000000  17966.000000
# mean    2016.866470  12279.534844   23362.608761    113.329456     57.906980
# std        2.050336   4741.343657   19472.054349     62.012456     10.125696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.500000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31060.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17966.000000
# mean       1.350807
# std        0.432367
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
df["price"].min()
# Out:
# 495

# %%
df["price"].max()
# Out:
# 54995

# %%
df["price"].mean()
# Out:
# np.float64(12279.534843593454)

# %%
df["price"].median()
# Out:
# 11291.0

# %%
df["mileage"].min()
# Out:
# 1

# %%
df["mileage"].max()
# Out:
# 177644

# %%
df["mileage"].mean()
# Out:
# np.float64(23362.608760992985)

# %%
df["mileage"].median()
# Out:
# 18242.5

# %%
df["year"].min()
# Out:
# 1996

# %%
df["year"].max()
# Out:
# 2060

# %%
df["year"].mean()
# Out:
# np.float64(2016.8664699988867)

# %%
df["year"].median()
# Out:
# 2017.0

# %%
plt.hist(df["price"])
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df["mileage"])
plt.xlabel("mileage")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df["year"])
plt.xlabel("year")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df["engineSize"])
plt.xlabel("engineSize")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df["mpg"])
plt.xlabel("mpg")
plt.ylabel("Frequency")
plt.show()

# %%
# Histograms show the distribution of numerical features.

# %%
sns.countplot(x = "fuelType", data = df)
plt.title("Fuel Type ")
# Out:
# Text(0.5, 1.0, 'Fuel Type ')

# %%
sns.countplot(x = "transmission", data = df)
plt.title("Transmission")
# Out:
# Text(0.5, 1.0, 'Transmission')

# %%
sns.countplot(x = "model", data = df)
plt.title("Model")
# Out:
# Text(0.5, 1.0, 'Model')

# %%
# Petrol cars are more common.
# Manual transmission is more common.

# %%
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
# Price is positively correlated with engine size.
# Mileage has a negative correlation with price.

# %%
X = df.drop("price",axis = 1)
X.columns
# Out:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')

# %%
y = df["price"]
y.head()
# Out:
# 0    12000
# 1    14000
# 2    13000
# 3    17500
# 4    16500
# Name: price, dtype: int64

# %%
# Independent Features = All columns except price.
# Dependent Feature = price.

# %%
df[["model","transmission"]].head()
# Out:
#     model transmission
# 0  Fiesta    Automatic
# 1   Focus       Manual
# 2   Focus       Manual
# 3  Fiesta       Manual
# 4  Fiesta    Automatic

# %%
df_encoded=pd.get_dummies(df)

# %%
df_encoded.head()
# Out:
#    year  price  mileage  tax   mpg  engineSize  model_B-MAX  model_C-MAX  \
# 0  2017  12000    15944  150  57.7         1.0        False        False
# 1  2018  14000     9083  150  57.7         1.0        False        False
# 2  2017  13000    12456  150  57.7         1.0        False        False
# 3  2019  17500    10460  145  40.3         1.5        False        False
# 4  2019  16500     1482  145  48.7         1.0        False        False
#
#    model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0           False       False  ...                 False
# 1           False       False  ...                 False
# 2           False       False  ...                 False
# 3           False       False  ...                 False
# 4           False       False  ...                 False
#
#    model_Transit Tourneo  transmission_Automatic  transmission_Manual  \
# 0                  False                    True                False
# ...

# %%
from sklearn.preprocessing import StandardScaler
X = df_encoded.drop("price",axis = 1)
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled[:5]
# Out:
# array([[ 0.06512772, -0.38099808,  0.59135805, -0.02044162, -0.81138621,
#         -0.14197836, -0.1765381 , -0.2606582 , -0.10822676, -0.00746082,
#          1.31908019, -0.58570599, -0.02985573, -0.11337443, -0.11806709,
#         -0.05740036, -0.10583261, -0.17451642, -0.37596624, -0.17366793,
#         -0.05641593, -0.06687879, -0.00746082, -0.1294278 , -0.01055148,
#         -0.04289735, -0.06209183, -0.00746082,  3.49293398, -2.51774746,
#         -0.25377066, -0.68712465, -0.01055148, -0.0350148 , -0.00746082,
#          0.68932007],
#        [ 0.55286624, -0.73335899,  0.59135805, -0.02044162, -0.81138621,
#         -0.14197836, -0.1765381 , -0.2606582 , -0.10822676, -0.00746082,
#         -0.75810402,  1.70734126, -0.02985573, -0.11337443, -0.11806709,
#         -0.05740036, -0.10583261, -0.17451642, -0.37596624, -0.17366793,
#         -0.05641593, -0.06687879, -0.00746082, -0.1294278 , -0.01055148,
#         -0.04289735, -0.06209183, -0.00746082, -0.28629227,  0.39718042,
# ...

# %%
# Load Dataset
# Missing Values
# Duplicate Values
# Histograms
# Count Plots
# Heatmap
# Feature Identification
# One Hot Encoding
# Feature Scaling
